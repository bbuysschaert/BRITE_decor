# %% [markdown]
# """
#
# So it is fairly common to do intrapixel correction in photometry. This is merely a correction for the fact that pixel is not uniformly sensitive and so there will be more (or less) light depending on where on the pixel it falls. This is a simple correction normally, but with BRITE unfortunately it's a lot more difficult. What we are going to correct here is hard to describe. Since BRITE is not cooled the PSF of the star changes with temperature. That means that where the light falls on the pixel also changes with temperature and not just with PSFs position. So simple intrapixel corrections don't work because the correction will change with temperature. We are going to take you through the correction step by step.
#
# Again we will import necessary modules and functions

# %%
import numpy as np

import scipy.interpolate as scInterp

import matplotlib.pyplot as plt

import statsmodels.api as sm

#BRITE routine
from BRITE_decor.inout import load_alt as load
from BRITE_decor.analysis import extra as be
import BRITE_decor.inout.OUTdetrendTempPSF as savePSFdetrendBRITE

import BRITE_decor.detrending.detrendTempPSF as PSFdetrendBRITE
import BRITE_decor.detrending.binningWtemperature as TEMPbinBRITE

import BRITE_decor.plotting.PLOTbinningWtemperature as plotTEMPbinBRITE
#enable inline plots
# %matplotlib inline

# %% [markdown]
# Like in the first tutorial, we need to load our data. This time our helper function won't create the file name for us, so we'll have to define our filename

# %%
filename = 'example_data/HD37043_OrionI-2013_UBr_setup7_orem.dat'

data,  columns, params = load.load_dataset(filename)

show_ME = False # show all plots (not practical for the notebook)
orbper = float(params['orbper'])

xPOS = data[:,columns['XCEN']]
FLUX = data[:,columns['FLUX']]
FLUX = (FLUX-np.mean(FLUX))/np.mean(FLUX)*1e3
data[:,columns['FLUX']] =FLUX

# %% [markdown]
# Alright, we have our data, but probably not a very good understanding of what we are trying to correct or why it is necessary. Additionally, we want to change the flux so that the values are not so large which can influence fitting. In our case we have changed to differential flux in ppt.  Also, a plot will better explain what is happening.

# %%
plt.figure()
plt.plot(xPOS, FLUX, 'k.', ms=2)

plt.show()

# %% [markdown]
# In this figure you can see what appears to be a very noisy sinusoidal pattern with a period of about 1 pixel? This is our intrapixel variation. But, this was already corrected for, before the data even got to us, so why do we still see it? Well, let's plot a phased diagram of this data and we'll see why. The easiest way to do this in python is just to take the number after the decimal which can be done with %1.

# %%
plt.figure()
plt.plot(xPOS%1, FLUX, 'k.', ms=2)
plt.xlabel('FLUX (ppt)')
plt.ylabel('Phase')
plt.show()

# %% [markdown]
# There doesn't look to be anything in the phase folded data, but we can SEE it in the non-phase folded data, so what is the issue? Well you remember how earlier I said that the variation changes with temperature? That is our problem. To emphasize this, let's plot only the data below and above a certain temperature.

# %%
temp = data[:,columns['CCDT']]
med_temp = np.median(temp)
plt.figure()

plt.plot(xPOS[temp > med_temp], FLUX[temp > med_temp], 'r.', ms=2, label='High Temp')
plt.plot(xPOS[temp < med_temp], FLUX[temp < med_temp], 'b.', ms=2, label='Low Temp')
plt.xlabel('X Position')
plt.ylabel('Flux (ppt)')
plt.legend()
plt.show()

# %% [markdown]
# And here is our smoking gun. The variations LOOK similar, but it's pretty clear to see that the two datasets are out of phase. Therefore, it's impossible to do an intrapixel correction on the entire dataset, because phase folding cancels outhe effect. However, if we split the data first as a function of temperature, this correction becomes much easier to make.
#
# We have a fancy function that does essentially this, but it's complicated. so an overview is necessary. The function "TEMPbinBRITE" Brite does the following:
#
# 1.) fits a lowess filter to the long term trend of temperature with time. From this it determines when there has been a change in temperature larger than a certain amount "TEMPcrit". The default is 2.5 degrees. Note: The reason we use a lowess filter here is because the temperature will change in orbit 4-5 degrees and this will mess up our ability to bin in any coherent way.
#
# 2.) In addition to this, if there are large gaps in the data, it is likely something problematic happened and the data on either side of the gap should be considered differently. To take this into account you set 'GAPsinclude' to True (default is False) and set the size of gap  'GAPScrit' that will stop a bin (default is 0.3 days).
#
#
# 3.) Finally we want to make sure our binsize is not too small as that can also affect adversely affect the data so we allow for a minimum binsize BINminSIZE (default 1 day).
#
# However, many of these are kwargs, which means they are not required inputs and defaults are in place (if necessary) when you do not specify them. All that is absolutely necessary are the temperature and time arrays.

# %%
HJD = data[:,columns['HJD']]

# %% [markdown]
# However, there are a couple of kwargs that we should set. The main one is the lowess filter fraction we learned about in the first tutorial. We also learned a good value is for time vs. temperature is 0.06. While this isn't particularly good for outlier rejection, it should work fine for these purposes. However, if the function is too sharp it will cause problems, so to be on the safe side let's set our lowess fraction value to 0.1.

# %%
frac = 0.1

# %% [markdown]
# Also, since the Orion I data has some very large gaps, we should take these into account in our function. The size of the gaps is a bit arbitrary, but 1 day seems like a reasonable value.

# %%
GAPSinclude = True
GAPScrit = 2.5

# %% [markdown]
# We don't have anymore insight right now, so let's run the function and see how well it works. And collect relevant information in the header.

# %%
binENDindexes, binENDindexes_reason, tempCCDLONG = TEMPbinBRITE.openTIMEwithTEMPERATURE(HJD, temp, GAPSinclude=GAPSinclude, GAPScrit=GAPScrit, LOWESSfrac=frac)


params['GAPSinclude'] = GAPSinclude
params['GAPScrit'] =GAPScrit
params['tempfrac'] = frac
# Out:
# 	Performing lowess filtering ...
# 	... all done.
#
# 	Initialising complete...
# 	End of bin: Gap			index    657 (at time 2.244 d) with a binlength of 2.244 d.
# 		tdiff = 6.761d;		gapSIZE limit is 2.500d.
# 	End of bin: Gap			index   1290 (at time 10.199 d) with a binlength of 1.194 d.
# 		tdiff = 3.274d;		gapSIZE limit is 2.500d.
# 	End of bin: Gap			index   1466 (at time 13.758 d) with a binlength of 0.285 d.
# 			WARNING: Timelength of this bin is smaller than the minimum length specified, i.e. 1.0d
# 		tdiff = 13.260d;		gapSIZE limit is 2.500d.
# 	End of bin: Gap			index   2891 (at time 29.876 d) with a binlength of 2.858 d.
# 		tdiff = 4.117d;		gapSIZE limit is 2.500d.
# 	End of bin: Gap			index   5551 (at time 43.823 d) with a binlength of 9.831 d.
# 		tdiff = 2.921d;		gapSIZE limit is 2.500d.
# 	End of bin: Gap			index   7556 (at time 53.243 d) with a binlength of 6.499 d.
# 		tdiff = 11.724d;		gapSIZE limit is 2.500d.
# 	End of bin: Temperature		index   8430 (at time 71.172 d) with a binlength of 6.204 d.
# 		Tdiff = -2.50deg;	dTEMP limit is +2.50deg.
# 	End of bin: Temperature		index  10651 (at time 78.423 d) with a binlength of 7.182 d.
# 		Tdiff = -2.52deg;	dTEMP limit is +2.50deg.
# 	End of bin: Temperature		index  11899 (at time 82.953 d) with a binlength of 4.460 d.
# 		Tdiff = -2.53deg;	dTEMP limit is +2.50deg.
# 	End of bin: Temperature		index  14496 (at time 88.466 d) with a binlength of 5.443 d.
# 		Tdiff = +0.00deg;	dTEMP limit is +2.50deg.
# 	End of bin: Temperature		index  18183 (at time 95.995 d) with a binlength of 7.463 d.
# 		Tdiff = +3.40deg;	dTEMP limit is +2.50deg.
# 	End of bin: Temperature		index  20117 (at time 100.040 d) with a binlength of 3.975 d.
# 		Tdiff = +2.50deg;	dTEMP limit is +2.50deg.
# 	End of bin: Temperature		index  22556 (at time 103.805 d) with a binlength of 3.696 d.
# 		Tdiff = +2.52deg;	dTEMP limit is +2.50deg.
# 	End of bin: Temperature		index  24385 (at time 107.083 d) with a binlength of 3.208 d.
# 		Tdiff = +2.54deg;	dTEMP limit is +2.50deg.
# 	End of bin: Temperature		index  25703 (at time 110.152 d) with a binlength of 2.999 d.
# 		Tdiff = +2.52deg;	dTEMP limit is +2.50deg.
# 	End of bin: Temperature		index  27258 (at time 113.012 d) with a binlength of 2.790 d.
# 		Tdiff = +2.56deg;	dTEMP limit is +2.50deg.
# 	End of bin: Temperature		index  28426 (at time 116.709 d) with a binlength of 3.627 d.
# 		Tdiff = +3.24deg;	dTEMP limit is +2.50deg.
# 	End of bin: Temperature		index  29823 (at time 119.639 d) with a binlength of 2.860 d.
# 		Tdiff = +2.50deg;	dTEMP limit is +2.50deg.
# 	End of bin: Temperature		index  30655 (at time 122.707 d) with a binlength of 3.000 d.
# 		Tdiff = +2.53deg;	dTEMP limit is +2.50deg.
# 	End of bin: END			index  32972 (at time 130.043 d) with a binlength of 7.406 d.
# 	... found all endpoints for timebins.

# %% [markdown]
# Now let's explain the output. binEndindexes is a long but descriptive name which essentially gives you the array index of the last element in for each of the chunks we have split our data into. binENDindexes_reason is mainly for bookkeeping. It tells us the reason the bin ended at the point, either because of the temperature change, or because it encountered a large gap. The final piece tempCCDLONG, is the lowess relation of the temperature as a function of time. It is returned, so that we can plot and make sure it looks as we expect. Speaking of which there is a convenience function which plots all the stuff you need to check how well your binning worked. This is surprisingly referred to as "PLOTopenTIMEwithTEMPERATURE". It takes all the outputs from before as well as the x position, yposition, time, and temperature and ... well let's just look at the output. It's easier that way.

# %%
yPOS = data[:,columns['YCEN']]

plotTEMPbinBRITE.PLOTopenTIMEwithTEMPERATURE(HJD, FLUX, temp, tempCCDLONG, xPOS, yPOS, binENDindexes, binENDindexes_reason)
plt.show()

# %% [markdown]
# So, there's a lot of info here, but the heart of it is the top plot. It gives time vs. temperature (black), the lowess relation (red) and the endpoints of each data chunk and whether it was caused by gaps (blue) or temperature change (green). The bottom three plots just show how this data is broken up for Flux, x position and y position. At first glance it looks reasonable. It might even look better if you have used the temperature gui to remove outliers. Now though, we must see how well the decorrelation goes. From here you can develop your own decorrelation routine if you like, but we have a couple for you. First let's try a simple intrapixel removal routine on each data block.
#
# Note: IN this function plot=False by default. You can change it to True, but just be prepared for about 20 plots.

# %%
flux_intcorrected = be.binnedINTRAPIXEL(FLUX, xPOS, yPOS, binENDindexes, plot=show_ME)

plt.figure()
plt.plot(HJD, FLUX, 'k.', ms=4) 
plt.plot(HJD, flux_intcorrected, 'r.', ms=2) 
plt.show()

# %% [markdown]
# This does a reasonably good job and it does something no other routine does which is allow us to do x and y corrections simultaneously. However if there are significant slopes or changes in amplitude, this method can suffer as is clear if you plotted all of the different comparisons in BRITE_extra.binnedINTRAPIXEL.
#
#
# If we want to take these variations into account, then we must
#
# 1.) Fit the data
# 2.) treat X and Y separately
#
# This time it will be slightly less convenient, but it will be for your own good.Instead, of having it loop over all the data internally, we are going to create our own for loop which slices the data into chunks and then fits each chunk.

# %%
init_ind = 0 # starting index

correction = [] # list to put corr
tckFIRSTstring = [] #list to 
tckSECONDstring = [] #
diagnostic = []  #
SPLINEstringLENGTH = 3000
SPLINEknotpointsSPACING = np.array([0.10, 0.12, 0.15, 0.17, 0.20, 0.22, 0.25,0.3, 0.35])#, 0.4, 0.45, 0.50])
SPLINEorder = np.array([1,3,5], dtype='int32') #you need to specify the integer type because the fitting function is tempermental

params['SPLINEstringLENGTH'] = SPLINEstringLENGTH
params['SPLINEknotpointsSPACING'] = list(SPLINEknotpointsSPACING)
params['SPLINEorder'] = list(SPLINEorder)

# %%
for i in range(len(binENDindexes)):
    
    print('THIS IS i '+str(i))
    fin_ind = binENDindexes[i]+1 # ending index

    datachunk = data[init_ind:fin_ind]  #slice the array on the given indices
    HJD_bin = datachunk[:,columns['HJD']]
    FLUX_bin = datachunk[:,columns['FLUX']]
    xPOS_bin = datachunk[:,columns['XCEN']]
    yPOS_bin = datachunk[:,columns['YCEN']]
    # Apply FIT


    correction_bin, tckFIRSTstring_bin, tckSECONDstring_bin, diagnostic_bin = PSFdetrendBRITE.detrendTEMPpsfFULL(HJD_bin, FLUX_bin, xPOS_bin, yPOS_bin, show_ME=False, SPLINEknotpointsSPACING = SPLINEknotpointsSPACING, SPLINEorder = SPLINEorder, SPLINEstringLENGTH =  SPLINEstringLENGTH)
    np.mean(correction_bin)

    correction.append(correction_bin)
    tckFIRSTstring.append(tckFIRSTstring_bin)
    tckSECONDstring.append(tckSECONDstring_bin)
    diagnostic.append(diagnostic_bin)

    #now move init_index up to a different chunk

    init_ind =  binENDindexes[i]+1
# Now concatenate so that there is one array for each output

correction = np.concatenate(correction)

# finally apply the correction to the flux

flux_fitcorrected = FLUX - correction
# Out:
# THIS IS i 0
# THIS IS i 1
# THIS IS i 2
# 	WARNING: AIC and BIC point towards a different coordinate / set of knotpoints
# 	Providing more information now...
# 	WARNING: AIC states 1 and BIC states 1 for the coordinate, where 0 = x and 1 = y
# 	WARNING: AIC states 0.350 and BIC states 0.300 for the spacing of the knotpoints
# 	WARNING: AIC states 0.060 and BIC states 0.200 for the phase shift of those sets of knotpoints
# 	WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 	WARNING: AIC states a minimum of 1.35684e+03, compared to 1.36808e+03 for the BIC optimal solution
# 	WARNING: BIC states a minimum of 1.26028e+03, compared to 1.26173e+03 for the AIC optimal solution
# 	WARNING: Likelihoods are 9.23340e+02 and 8.75098e+02, for AIC and BIC respectively
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.350 and BIC states 0.300 for the spacing of the knotpoints
# 		WARNING: AIC states 0.320 and BIC states 0.050 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 		WARNING: AIC states a minimum of 1.36150e+03, compared to 1.36423e+03 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 1.23107e+03, compared to 1.24736e+03 for the AIC optimal solution
# 		WARNING: Likelihoods are 7.94882e+02 and 6.76856e+02, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 3
# 	WARNING: AIC and BIC point towards a different coordinate / set of knotpoints
# 	Providing more information now...
# 	WARNING: AIC states 1 and BIC states 0 for the coordinate, where 0 = x and 1 = y
# 	WARNING: AIC states 0.350 and BIC states 0.170 for the spacing of the knotpoints
# 	WARNING: AIC states 0.110 and BIC states 0.020 for the phase shift of those sets of knotpoints
# 	WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 	WARNING: AIC states a minimum of 1.28198e+04, compared to 1.30937e+04 for the BIC optimal solution
# 	WARNING: BIC states a minimum of 1.26412e+04, compared to 1.26514e+04 for the AIC optimal solution
# 	WARNING: Likelihoods are 6.85863e+03 and 6.31257e+03, for AIC and BIC respectively
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.300 and BIC states 0.220 for the spacing of the knotpoints
# 		WARNING: AIC states 0.160 and BIC states 0.080 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 		WARNING: AIC states a minimum of 1.27106e+04, compared to 1.27674e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 1.24201e+04, compared to 1.24475e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 5.79586e+03 and 5.55937e+03, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 4
# 	WARNING: AIC and BIC point towards a different coordinate / set of knotpoints
# 	Providing more information now...
# 	WARNING: AIC states 0 and BIC states 0 for the coordinate, where 0 = x and 1 = y
# 	WARNING: AIC states 0.300 and BIC states 0.150 for the spacing of the knotpoints
# 	WARNING: AIC states 0.290 and BIC states 0.020 for the phase shift of those sets of knotpoints
# 	WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 	WARNING: AIC states a minimum of 2.60104e+04, compared to 2.62240e+04 for the BIC optimal solution
# 	WARNING: BIC states a minimum of 2.56590e+04, compared to 2.57278e+04 for the AIC optimal solution
# 	WARNING: Likelihoods are 1.53065e+04 and 1.43866e+04, for AIC and BIC respectively
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 5
# 	WARNING: AIC and BIC point towards a different coordinate / set of knotpoints
# 	Providing more information now...
# 	WARNING: AIC states 0 and BIC states 0 for the coordinate, where 0 = x and 1 = y
# 	WARNING: AIC states 0.300 and BIC states 0.250 for the spacing of the knotpoints
# 	WARNING: AIC states 0.010 and BIC states 0.010 for the phase shift of those sets of knotpoints
# 	WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 	WARNING: AIC states a minimum of 1.93718e+04, compared to 1.93881e+04 for the BIC optimal solution
# 	WARNING: BIC states a minimum of 1.90743e+04, compared to 1.91028e+04 for the AIC optimal solution
# 	WARNING: Likelihoods are 1.30914e+04 and 1.28041e+04, for AIC and BIC respectively
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.200 and BIC states 0.200 for the spacing of the knotpoints
# 		WARNING: AIC states 0.030 and BIC states 0.010 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 3.000 for the order of the spline
# 		WARNING: AIC states a minimum of 1.94594e+04, compared to 1.97328e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 1.91276e+04, compared to 1.91457e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 1.32678e+04 and 1.24844e+04, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 6
# THIS IS i 7
# 	WARNING: AIC and BIC point towards a different coordinate / set of knotpoints
# 	Providing more information now...
# 	WARNING: AIC states 0 and BIC states 0 for the coordinate, where 0 = x and 1 = y
# 	WARNING: AIC states 0.200 and BIC states 0.170 for the spacing of the knotpoints
# 	WARNING: AIC states 0.130 and BIC states 0.060 for the phase shift of those sets of knotpoints
# 	WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 	WARNING: AIC states a minimum of 2.17748e+04, compared to 2.17999e+04 for the BIC optimal solution
# 	WARNING: BIC states a minimum of 2.12978e+04, compared to 2.13525e+04 for the AIC optimal solution
# 	WARNING: Likelihoods are 1.38865e+04 and 1.33794e+04, for AIC and BIC respectively
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.350 and BIC states 0.150 for the spacing of the knotpoints
# 		WARNING: AIC states 0.010 and BIC states 0.070 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 3.000 for the order of the spline
# 		WARNING: AIC states a minimum of 2.32189e+04, compared to 2.34865e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 2.27104e+04, compared to 2.30477e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 3.09728e+04 and 2.41918e+04, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 8
# 	WARNING: AIC and BIC point towards a different coordinate / set of knotpoints
# 	Providing more information now...
# 	WARNING: AIC states 0 and BIC states 0 for the coordinate, where 0 = x and 1 = y
# 	WARNING: AIC states 0.300 and BIC states 0.250 for the spacing of the knotpoints
# 	WARNING: AIC states 0.290 and BIC states 0.120 for the phase shift of those sets of knotpoints
# 	WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 	WARNING: AIC states a minimum of 1.12119e+04, compared to 1.12388e+04 for the BIC optimal solution
# 	WARNING: BIC states a minimum of 1.09414e+04, compared to 1.09658e+04 for the AIC optimal solution
# 	WARNING: Likelihoods are 6.14732e+03 and 5.93224e+03, for AIC and BIC respectively
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.300 and BIC states 0.250 for the spacing of the knotpoints
# 		WARNING: AIC states 0.140 and BIC states 0.140 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 3.000 for the order of the spline
# 		WARNING: AIC states a minimum of 1.22052e+04, compared to 1.22993e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 1.19096e+04, compared to 1.20411e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 1.49497e+04 and 1.25354e+04, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 9
# 	WARNING: AIC and BIC point towards a different coordinate / set of knotpoints
# 	Providing more information now...
# 	WARNING: AIC states 0 and BIC states 0 for the coordinate, where 0 = x and 1 = y
# 	WARNING: AIC states 0.350 and BIC states 0.300 for the spacing of the knotpoints
# 	WARNING: AIC states 0.190 and BIC states 0.140 for the phase shift of those sets of knotpoints
# 	WARNING: AIC states 1.000 and BIC states 3.000 for the order of the spline
# 	WARNING: AIC states a minimum of 2.52584e+04, compared to 2.54509e+04 for the BIC optimal solution
# 	WARNING: BIC states a minimum of 2.48884e+04, compared to 2.50123e+04 for the AIC optimal solution
# 	WARNING: Likelihoods are 1.51361e+04 and 1.38396e+04, for AIC and BIC respectively
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 10
# 	WARNING: AIC and BIC point towards a different coordinate / set of knotpoints
# 	Providing more information now...
# 	WARNING: AIC states 0 and BIC states 0 for the coordinate, where 0 = x and 1 = y
# 	WARNING: AIC states 0.250 and BIC states 0.100 for the spacing of the knotpoints
# 	WARNING: AIC states 0.100 and BIC states 0.000 for the phase shift of those sets of knotpoints
# 	WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 	WARNING: AIC states a minimum of 3.73341e+04, compared to 3.77759e+04 for the BIC optimal solution
# 	WARNING: BIC states a minimum of 3.68926e+04, compared to 3.69733e+04 for the AIC optimal solution
# 	WARNING: Likelihoods are 2.02495e+04 and 1.89385e+04, for AIC and BIC respectively
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.350 and BIC states 0.300 for the spacing of the knotpoints
# 		WARNING: AIC states 0.140 and BIC states 0.200 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 5.000 for the order of the spline
# 		WARNING: AIC states a minimum of 4.00503e+04, compared to 4.03039e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 3.96321e+04, compared to 3.98513e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 4.45397e+04 and 4.03065e+04, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 11
# THIS IS i 12
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.250 and BIC states 0.220 for the spacing of the knotpoints
# 		WARNING: AIC states 0.020 and BIC states 0.090 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 5.000 for the order of the spline
# 		WARNING: AIC states a minimum of 2.47135e+04, compared to 2.54183e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 2.43063e+04, compared to 2.43775e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 2.25938e+04 and 1.96385e+04, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 13
# THIS IS i 14
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.350 and BIC states 0.120 for the spacing of the knotpoints
# 		WARNING: AIC states 0.250 and BIC states 0.000 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 		WARNING: AIC states a minimum of 1.19053e+04, compared to 1.21704e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 1.17246e+04, compared to 1.17498e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 7.11047e+03 and 6.40744e+03, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 15
# 	WARNING: AIC and BIC point towards a different coordinate / set of knotpoints
# 	Providing more information now...
# 	WARNING: AIC states 0 and BIC states 0 for the coordinate, where 0 = x and 1 = y
# 	WARNING: AIC states 0.250 and BIC states 0.170 for the spacing of the knotpoints
# 	WARNING: AIC states 0.160 and BIC states 0.130 for the phase shift of those sets of knotpoints
# 	WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 	WARNING: AIC states a minimum of 1.47745e+04, compared to 1.48055e+04 for the BIC optimal solution
# 	WARNING: BIC states a minimum of 1.43562e+04, compared to 1.44643e+04 for the AIC optimal solution
# 	WARNING: Likelihoods are 1.02306e+04 and 9.22905e+03, for AIC and BIC respectively
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.220 and BIC states 0.170 for the spacing of the knotpoints
# 		WARNING: AIC states 0.130 and BIC states 0.020 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 		WARNING: AIC states a minimum of 1.51795e+04, compared to 1.52376e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 1.48952e+04, compared to 1.49228e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 1.39195e+04 and 1.33963e+04, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 16
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.300 and BIC states 0.200 for the spacing of the knotpoints
# 		WARNING: AIC states 0.230 and BIC states 0.120 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 		WARNING: AIC states a minimum of 1.06051e+04, compared to 1.06201e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 1.03579e+04, compared to 1.04236e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 8.50635e+03 and 7.81018e+03, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 17
# 	WARNING: AIC and BIC point towards a different coordinate / set of knotpoints
# 	Providing more information now...
# 	WARNING: AIC states 0 and BIC states 0 for the coordinate, where 0 = x and 1 = y
# 	WARNING: AIC states 0.300 and BIC states 0.250 for the spacing of the knotpoints
# 	WARNING: AIC states 0.050 and BIC states 0.110 for the phase shift of those sets of knotpoints
# 	WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 	WARNING: AIC states a minimum of 1.27404e+04, compared to 1.27511e+04 for the BIC optimal solution
# 	WARNING: BIC states a minimum of 1.24363e+04, compared to 1.24781e+04 for the AIC optimal solution
# 	WARNING: Likelihoods are 6.74324e+03 and 6.45303e+03, for AIC and BIC respectively
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.350 and BIC states 0.350 for the spacing of the knotpoints
# 		WARNING: AIC states 0.150 and BIC states 0.010 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 3.000 for the order of the spline
# 		WARNING: AIC states a minimum of 1.29635e+04, compared to 1.31234e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 1.27875e+04, compared to 1.27956e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 8.67430e+03 and 8.24010e+03, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 18
# THIS IS i 19
# 	WARNING: AIC and BIC point towards a different coordinate / set of knotpoints
# 	Providing more information now...
# 	WARNING: AIC states 1 and BIC states 1 for the coordinate, where 0 = x and 1 = y
# 	WARNING: AIC states 0.350 and BIC states 0.250 for the spacing of the knotpoints
# 	WARNING: AIC states 0.250 and BIC states 0.100 for the phase shift of those sets of knotpoints
# 	WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 	WARNING: AIC states a minimum of 2.21574e+04, compared to 2.21655e+04 for the BIC optimal solution
# 	WARNING: BIC states a minimum of 2.18892e+04, compared to 2.19616e+04 for the AIC optimal solution
# 	WARNING: Likelihoods are 1.16172e+04 and 1.11290e+04, for AIC and BIC respectively
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD

# %% [markdown]
# Okay, so before we just sit we are fitting the data, but that function did A LOT. So let's discuss what is going on here and what it means so that if we actually need to change what's being done at some point in the future, you don't have to dive into the code to make sense of it. This function basically fits a bunch of spline functions and picks the best one based on two different information criteria: bayesian and akaike. You can provide the spline values for fitting like the knot spacing and the polynomial order and it will create hundreds of different combinations of these and find the one that best fits to the data. There is only one problem with this fitting procedure which is that it's prone to failure when the data clipping isn't rigorous enough. This is a large part of the reason for clipping outliers from several different parameters in the first tutorial.
#
#
# Now let's plot the result and see how we did.

# %%
plt.figure()
plt.plot(HJD, FLUX, 'k.')
plt.plot(HJD, flux_fitcorrected, 'r.')
plt.show()

# %% [markdown]
# We did pretty good. Now let's add the intrapixel correction and see how it compares.

# %%
plt.figure()
plt.plot(HJD, FLUX, 'k.')

plt.plot(HJD, flux_intcorrected, 'g.', ms=2., label='intrapixel')
plt.plot(HJD, flux_fitcorrected, 'r.', ms=2., label='fit')
plt.legend(prop={'size':12})
plt.show()

# %% [markdown]
# By Eye, these are surprisingly close with the fit looking a bit better. However, to really get a good idea we could have to calculate the rms error for each dataset. Fortunately there is a convenience function for this, so let's do that below.

# %%
err_int = be.data_err(HJD, flux_intcorrected, orbper)

err_fit = be.data_err(HJD, flux_fitcorrected, orbper)

print "Error Intrapixel", err_int

print "Error Fit", err_fit
# Out:
# Error Intrapixel 1.16410960292
# Error Fit 1.12685618762

# %% [markdown]
# This shows us that the fit corrected is better, at least marginally. For now though, there is one very important thing to notice: the longterm trend in flux doesn't seem to be affected by this correction at all. So, what would happen if we removed it before doing all these things, say with a lowess filter. Now keep in mind this can be dangerous, but we won't lose the longterm trend, because we will add it back in at the end. This is entirely optional, but it gives us something interesting to try and it might make our corrections much better.

# %%
frac=0.1
FLUXlowess = sm.nonparametric.lowess(FLUX, HJD, frac=frac)
time_l, FLUX_l = FLUXlowess[:,0], FLUXlowess[:,1]

plt.figure()
plt.plot(HJD, FLUX, 'k.', markersize=2.0)
plt.plot(time_l, FLUX_l, 'r', lw=2.0)
plt.show()
FLUX_subtracted = FLUX-FLUX_l

# %% [markdown]
# Now let's see what difference it has, on the intrapixel correction.

# %%
flux_intcorrected_subtracted = be.binnedINTRAPIXEL(FLUX_subtracted, xPOS, yPOS, binENDindexes, plot=show_ME)

flux_intcorrected_new = FLUX_l+flux_intcorrected_subtracted #add back the subtracted flux

plt.figure()
plt.plot(HJD, FLUX, 'k.')
plt.plot(HJD, flux_intcorrected, 'r.', ms=2.0, label='New Correction')
plt.plot(HJD, flux_intcorrected_new, 'g.', ms=2.0, label='New Correction')

err_int_ls = be.data_err(HJD, flux_intcorrected_new, orbper)
print "ERROR Intrapixel Longterm trend subtracted", err_int_ls

pl.show()
# Out:
# ERROR Intrapixel Longterm trend subtracted 1.16298051847

# %% [markdown]
# So, maybe a little improvement, but not a ton. What happens when we do the same thing for our fitting routine.

# %%
init_ind = 0 # starting index

correction = [] # list to put corr
tckFIRSTstring = [] #list to 
tckSECONDstring = [] #
diagnostic = []  #
SPLINEstringLENGTH = 3000

datan = np.copy(data) #need to make a copy so that we don't replace the real data
datan[:,columns['FLUX']] = FLUX_subtracted #change the flux column
#SPLINEknotpointsSPACING = np.array([0.1, 0.2,0.25,1./3.])
for i in range(len(binENDindexes)):
#for i in range(3,len(binENDindexes)):
    print('THIS IS i '+str(i))
    fin_ind = binENDindexes[i]+1 # ending index

    datachunk = datan[init_ind:fin_ind]  #slice the array on the given indices
    HJD_bin = datachunk[:,columns['HJD']]
    FLUX_bin = datachunk[:,columns['FLUX']]
    xPOS_bin = datachunk[:,columns['XCEN']]
    yPOS_bin = datachunk[:,columns['YCEN']]
    # Apply FIT


    correction_bin, tckFIRSTstring_bin, tckSECONDstring_bin, diagnostic_bin = PSFdetrendBRITE.detrendTEMPpsfFULL(HJD_bin, FLUX_bin, xPOS_bin, yPOS_bin, show_ME=show_ME, SPLINEknotpointsSPACING = SPLINEknotpointsSPACING, SPLINEorder = SPLINEorder, SPLINEstringLENGTH =  SPLINEstringLENGTH)
#    correction_bin, tckFIRSTstring_bin, tckSECONDstring_bin, diagnostic_bin = PSFdetrendBRITE.detrendTEMPpsfFULL(HJD_bin, FLUX_bin, xPOS_bin, yPOS_bin, show_ME=True, SPLINEknotpointsSPACING = np.array([1.]), SPLINEorder = np.array([3,5], dtype='int32'), SPLINEstringLENGTH =  SPLINEstringLENGTH)

    correction.append(correction_bin)
    tckFIRSTstring.append(tckFIRSTstring_bin)
    tckSECONDstring.append(tckSECONDstring_bin)
    diagnostic.append(diagnostic_bin)

    #now move init_index up to a different chunk

    init_ind =  binENDindexes[i]+1
# Now concatenate so that there is one array for each output

ncorrection = np.concatenate(correction)
#tckFIRSTstring = np.concatenate(tckFIRSTstring)         
#tckSECONDstring = np.concatenate(tckSECONDstring)
#diagnostic = np.concatenate(diagnostic)

# finally apply the correction to the flux

flux_fitcorrectedn = FLUX - ncorrection
# Out:
# THIS IS i 0
# THIS IS i 1
# THIS IS i 2
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.350 and BIC states 0.300 for the spacing of the knotpoints
# 		WARNING: AIC states 0.320 and BIC states 0.050 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 		WARNING: AIC states a minimum of 1.36422e+03, compared to 1.36667e+03 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 1.23351e+03, compared to 1.25009e+03 for the AIC optimal solution
# 		WARNING: Likelihoods are 8.07283e+02 and 6.86285e+02, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 3
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.300 and BIC states 0.250 for the spacing of the knotpoints
# 		WARNING: AIC states 0.110 and BIC states 0.210 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 		WARNING: AIC states a minimum of 1.27558e+04, compared to 1.27937e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 1.24885e+04, compared to 1.24928e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 5.98294e+03 and 5.89839e+03, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 4
# 	WARNING: AIC and BIC point towards a different coordinate / set of knotpoints
# 	Providing more information now...
# 	WARNING: AIC states 0 and BIC states 0 for the coordinate, where 0 = x and 1 = y
# 	WARNING: AIC states 0.300 and BIC states 0.170 for the spacing of the knotpoints
# 	WARNING: AIC states 0.100 and BIC states 0.040 for the phase shift of those sets of knotpoints
# 	WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 	WARNING: AIC states a minimum of 2.60673e+04, compared to 2.61381e+04 for the BIC optimal solution
# 	WARNING: BIC states a minimum of 2.56319e+04, compared to 2.57730e+04 for the AIC optimal solution
# 	WARNING: Likelihoods are 1.55454e+04 and 1.43485e+04, for AIC and BIC respectively
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.300 and BIC states 0.200 for the spacing of the knotpoints
# 		WARNING: AIC states 0.070 and BIC states 0.140 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 		WARNING: AIC states a minimum of 2.63079e+04, compared to 2.63314e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 2.59900e+04, compared to 2.60725e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 1.75288e+04 and 1.67655e+04, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 5
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.300 and BIC states 0.200 for the spacing of the knotpoints
# 		WARNING: AIC states 0.070 and BIC states 0.050 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 		WARNING: AIC states a minimum of 1.94993e+04, compared to 1.95630e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 1.92492e+04, compared to 1.92863e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 1.44899e+04 and 1.39710e+04, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 6
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.300 and BIC states 0.350 for the spacing of the knotpoints
# 		WARNING: AIC states 0.070 and BIC states 0.060 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 3.000 for the order of the spline
# 		WARNING: AIC states a minimum of 8.20046e+03, compared to 8.36212e+03 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 7.95751e+03, compared to 7.96926e+03 for the AIC optimal solution
# 		WARNING: Likelihoods are 5.56082e+03 and 5.07345e+03, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 7
# THIS IS i 8
# 	WARNING: AIC and BIC point towards a different coordinate / set of knotpoints
# 	Providing more information now...
# 	WARNING: AIC states 0 and BIC states 0 for the coordinate, where 0 = x and 1 = y
# 	WARNING: AIC states 0.300 and BIC states 0.220 for the spacing of the knotpoints
# 	WARNING: AIC states 0.150 and BIC states 0.050 for the phase shift of those sets of knotpoints
# 	WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 	WARNING: AIC states a minimum of 1.11914e+04, compared to 1.12737e+04 for the BIC optimal solution
# 	WARNING: BIC states a minimum of 1.09352e+04, compared to 1.09453e+04 for the AIC optimal solution
# 	WARNING: Likelihoods are 6.04685e+03 and 5.82750e+03, for AIC and BIC respectively
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 9
# 	WARNING: AIC and BIC point towards a different coordinate / set of knotpoints
# 	Providing more information now...
# 	WARNING: AIC states 0 and BIC states 0 for the coordinate, where 0 = x and 1 = y
# 	WARNING: AIC states 0.350 and BIC states 0.350 for the spacing of the knotpoints
# 	WARNING: AIC states 0.030 and BIC states 0.310 for the phase shift of those sets of knotpoints
# 	WARNING: AIC states 1.000 and BIC states 5.000 for the order of the spline
# 	WARNING: AIC states a minimum of 2.51018e+04, compared to 2.55502e+04 for the BIC optimal solution
# 	WARNING: BIC states a minimum of 2.48119e+04, compared to 2.48557e+04 for the AIC optimal solution
# 	WARNING: Likelihoods are 1.42479e+04 and 1.31292e+04, for AIC and BIC respectively
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.200 and BIC states 0.200 for the spacing of the knotpoints
# 		WARNING: AIC states 0.080 and BIC states 0.130 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 5.000 for the order of the spline
# 		WARNING: AIC states a minimum of 2.69534e+04, compared to 2.73614e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 2.64825e+04, compared to 2.66487e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 2.82522e+04 and 2.45650e+04, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 10
# 	WARNING: AIC and BIC point towards a different coordinate / set of knotpoints
# 	Providing more information now...
# 	WARNING: AIC states 0 and BIC states 0 for the coordinate, where 0 = x and 1 = y
# 	WARNING: AIC states 0.250 and BIC states 0.120 for the spacing of the knotpoints
# 	WARNING: AIC states 0.150 and BIC states 0.070 for the phase shift of those sets of knotpoints
# 	WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 	WARNING: AIC states a minimum of 3.71738e+04, compared to 3.74686e+04 for the BIC optimal solution
# 	WARNING: BIC states a minimum of 3.67346e+04, compared to 3.68130e+04 for the AIC optimal solution
# 	WARNING: Likelihoods are 1.93947e+04 and 1.83864e+04, for AIC and BIC respectively
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.250 and BIC states 0.300 for the spacing of the knotpoints
# 		WARNING: AIC states 0.160 and BIC states 0.190 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 5.000 for the order of the spline
# 		WARNING: AIC states a minimum of 4.00933e+04, compared to 4.03697e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 3.96978e+04, compared to 3.98321e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 4.40722e+04 and 4.10261e+04, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 11
# 	WARNING: AIC and BIC point towards a different coordinate / set of knotpoints
# 	Providing more information now...
# 	WARNING: AIC states 0 and BIC states 0 for the coordinate, where 0 = x and 1 = y
# 	WARNING: AIC states 0.300 and BIC states 0.300 for the spacing of the knotpoints
# 	WARNING: AIC states 0.260 and BIC states 0.270 for the phase shift of those sets of knotpoints
# 	WARNING: AIC states 1.000 and BIC states 3.000 for the order of the spline
# 	WARNING: AIC states a minimum of 1.85656e+04, compared to 1.87318e+04 for the BIC optimal solution
# 	WARNING: BIC states a minimum of 1.81979e+04, compared to 1.82986e+04 for the AIC optimal solution
# 	WARNING: Likelihoods are 1.29736e+04 and 1.17116e+04, for AIC and BIC respectively
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.250 and BIC states 0.120 for the spacing of the knotpoints
# 		WARNING: AIC states 0.060 and BIC states 0.060 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 3.000 for the order of the spline
# 		WARNING: AIC states a minimum of 1.94840e+04, compared to 1.99957e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 1.90169e+04, compared to 1.92393e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 2.12528e+04 and 1.65014e+04, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 12
# THIS IS i 13
# THIS IS i 14
# 	WARNING: AIC and BIC point towards a different coordinate / set of knotpoints
# 	Providing more information now...
# 	WARNING: AIC states 0 and BIC states 0 for the coordinate, where 0 = x and 1 = y
# 	WARNING: AIC states 0.250 and BIC states 0.170 for the spacing of the knotpoints
# 	WARNING: AIC states 0.110 and BIC states 0.150 for the phase shift of those sets of knotpoints
# 	WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 	WARNING: AIC states a minimum of 1.21409e+04, compared to 1.21439e+04 for the BIC optimal solution
# 	WARNING: BIC states a minimum of 1.17084e+04, compared to 1.18402e+04 for the AIC optimal solution
# 	WARNING: Likelihoods are 7.29862e+03 and 6.34881e+03, for AIC and BIC respectively
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.350 and BIC states 0.170 for the spacing of the knotpoints
# 		WARNING: AIC states 0.250 and BIC states 0.010 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 		WARNING: AIC states a minimum of 1.19212e+04, compared to 1.20162e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 1.17051e+04, compared to 1.17657e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 7.19685e+03 and 6.56788e+03, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 15
# 	WARNING: AIC and BIC point towards a different coordinate / set of knotpoints
# 	Providing more information now...
# 	WARNING: AIC states 0 and BIC states 0 for the coordinate, where 0 = x and 1 = y
# 	WARNING: AIC states 0.250 and BIC states 0.150 for the spacing of the knotpoints
# 	WARNING: AIC states 0.160 and BIC states 0.120 for the phase shift of those sets of knotpoints
# 	WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 	WARNING: AIC states a minimum of 1.47094e+04, compared to 1.48500e+04 for the BIC optimal solution
# 	WARNING: BIC states a minimum of 1.43366e+04, compared to 1.43992e+04 for the AIC optimal solution
# 	WARNING: Likelihoods are 9.81074e+03 and 8.97353e+03, for AIC and BIC respectively
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 	Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.200 and BIC states 0.100 for the spacing of the knotpoints
# 		WARNING: AIC states 0.170 and BIC states 0.070 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 		WARNING: AIC states a minimum of 1.51988e+04, compared to 1.54745e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 1.49183e+04, compared to 1.49207e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 1.38293e+04 and 1.29141e+04, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 16
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.250 and BIC states 0.120 for the spacing of the knotpoints
# 		WARNING: AIC states 0.190 and BIC states 0.060 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 1.000 for the order of the spline
# 		WARNING: AIC states a minimum of 1.05678e+04, compared to 1.06497e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 1.02161e+04, compared to 1.03560e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 7.93492e+03 and 6.50151e+03, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 17
# 		WARNING: AIC and BIC point towards a different set of knotpoints
# 		Providing more information now...
# 		WARNING: AIC states 0.250 and BIC states 0.250 for the spacing of the knotpoints
# 		WARNING: AIC states 0.210 and BIC states 0.160 for the phase shift of those sets of knotpoints
# 		WARNING: AIC states 1.000 and BIC states 3.000 for the order of the spline
# 		WARNING: AIC states a minimum of 1.29138e+04, compared to 1.30844e+04 for the BIC optimal solution
# 		WARNING: BIC states a minimum of 1.26227e+04, compared to 1.26829e+04 for the AIC optimal solution
# 		WARNING: Likelihoods are 7.86949e+03 and 7.08100e+03, for AIC and BIC respectively
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# 		Taking the AIC as best solution, indicated by the LIKELIHOOD
# THIS IS i 18
# THIS IS i 19

# %%
plt.figure()
plt.plot(HJD, FLUX, 'k.')
plt.plot(HJD, flux_fitcorrected, 'r.', ms=2.0, label='Correction')
plt.plot(HJD, flux_fitcorrectedn, 'g.', ms=2.0, label='New Correction')

err_fit_ls = be.data_err(HJD, flux_fitcorrectedn, orbper)
print "ERROR Fit longterm trend subtraction", err_fit_ls
plt.show()
# Out:
# ERROR Fit longterm trend subtraction 1.1165599023

# %% [markdown]
# Again NOT a huge improvement, but your dataset might be different. This is giving you one more tool to try. It might help, or it might not but at least you are prepared. And now that we have done all of this let's save our file and move on to fitting. Oh, and you can choose what flux to take at this point. I will take flux fit corrected but not the trend subtracted as there is not a significant difference. Again, take NOTE of the correction so that you can refer to it later.

# %%
data[:,columns['FLUX']] = flux_fitcorrected #flux_intcorrected_new


params['flux_correction'] = 'spline fit' #other keywords could be 'intrapixel', 'detrended spline fit', 'detrended intrapixel'

# %% [markdown]
# And since we have our header dictionary let's use it, for no other reason than to get keywords for defining our filename. This is purely arbitrary, but it's kind of fun.

# %%
targ = params['StarInFo'].split(',')[0]
obsid= params['FieldIDn'].split('_')[1]
tel = params['SatellID']
setup = params['IFilSetN']

filename = str(targ)+'_'+str(obsid)+'_'+str(tel)+'_'+str(setup)+'_opsfrem.dat'

load.save_dataset(filename, data, columns=columns, params=params)
# Out:
# There is no column "FLAG" to delete
